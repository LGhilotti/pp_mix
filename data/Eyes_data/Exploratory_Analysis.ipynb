# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # EYE SCANS
#
# https://www.nature.com/articles/s41598-021-02025-4#Sec2

# %%
df = pd.read_excel("41598_2021_2025_MOESM2_ESM.xlsx")

# %%
df.head()
# Out:
#   Masked_Id_Age1  Cluster_Id_Age1        V1        V2        V3        V4  \
# 0        13435OD                7  0.003646  0.003648  0.003655  0.003665
# 1        13435OS                7  0.003458  0.003357  0.003408  0.003464
# 2        13564OD                7  0.002993  0.003013  0.003042  0.003078
# 3        13564OS                2  0.002174  0.002197  0.002232  0.002273
# 4        13587OD                1  0.002907  0.002940  0.002982  0.003034
#
#          V5        V6        V7        V8  ...      V171      V172      V173  \
# 0  0.003679  0.003696  0.003715  0.003737  ...  0.003696  0.003691  0.003686
# 1  0.003518  0.003567  0.003613  0.003657  ...  0.003798  0.003740  0.003687
# 2  0.003116  0.003152  0.003181  0.003205  ...  0.002988  0.002996  0.003002
# 3  0.002320  0.002376  0.002441  0.002515  ...  0.002558  0.002520  0.002481
# 4  0.003097  0.003177  0.003275  0.003396  ...  0.002913  0.002900  0.002885
#
#        V174      V175      V176      V177      V178      V179      V180
# 0  0.003680  0.003674  0.003668  0.003662  0.003656  0.003651  0.003647
# 1  0.003639  0.003597  0.003561  0.003529  0.003500  0.003477  0.003462
# 2  0.003004  0.003002  0.002996  0.002989  0.002982  0.002979  0.002982
# 3  0.002443  0.002404  0.002362  0.002317  0.002273  0.002232  0.002198
# 4  0.002869  0.002855  0.002845  0.002844  0.002850  0.002862  0.002881
#
# [5 rows x 182 columns]

# %%
df.shape
# Out:
# (1841, 182)

# %%
vals = df[df.columns[2:]].values

# %%
plt.plot(vals[np.random.choice(1800, 50)].T)
plt.show()

# %%
def shift(v, ind):
    return np.concatenate([v[ind:], v[:ind]])

# %%
ind1 = -50
ind2 = 10
ind3 = 1200

theta = np.linspace(0, 2 * np.pi, vals.shape[1])
dx = theta[1] - theta[0]

# %%
fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, polar=True)

ax.plot(theta, vals[np.random.choice(1800, 10),:].T)
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.tight_layout()
plt.savefig("ex_data_circ.pdf")
plt.show()

# %%
# extract only right eyes (OD)
df_od = df.loc[df['Masked_Id_Age1'].str.contains("OD", case=True)].set_index('Masked_Id_Age1')
cifu_clustering = df_od['Cluster_Id_Age1']
df_od = df_od[df_od.columns[1:]]

# %%
df_od.head()
# Out:
#                       V1        V2        V3        V4        V5        V6  \
# Masked_Id_Age1
# 13435OD         0.003646  0.003648  0.003655  0.003665  0.003679  0.003696
# 13564OD         0.002993  0.003013  0.003042  0.003078  0.003116  0.003152
# 13587OD         0.002907  0.002940  0.002982  0.003034  0.003097  0.003177
# 13588OD         0.003334  0.003378  0.003451  0.003552  0.003674  0.003811
# 13743OD         0.004369  0.004352  0.004336  0.004315  0.004286  0.004247
#
#                       V7        V8        V9       V10  ...      V171  \
# Masked_Id_Age1                                          ...
# 13435OD         0.003715  0.003737  0.003762  0.003791  ...  0.003696
# 13564OD         0.003181  0.003205  0.003225  0.003243  ...  0.002988
# 13587OD         0.003275  0.003396  0.003538  0.003699  ...  0.002913
# 13588OD         0.003956  0.004098  0.004232  0.004352  ...  0.003925
# 13743OD         0.004202  0.004156  0.004112  0.004072  ...  0.004831
#
#                     V172      V173      V174      V175      V176      V177  \
# Masked_Id_Age1
# 13435OD         0.003691  0.003686  0.003680  0.003674  0.003668  0.003662
# 13564OD         0.002996  0.003002  0.003004  0.003002  0.002996  0.002989
# 13587OD         0.002900  0.002885  0.002869  0.002855  0.002845  0.002844
# 13588OD         0.003836  0.003745  0.003655  0.003567  0.003488  0.003420
# 13743OD         0.004795  0.004747  0.004690  0.004628  0.004567  0.004511
#
#                     V178      V179      V180
# Masked_Id_Age1
# 13435OD         0.003656  0.003651  0.003647
# 13564OD         0.002982  0.002979  0.002982
# 13587OD         0.002850  0.002862  0.002881
# 13588OD         0.003367  0.003332  0.003320
# 13743OD         0.004462  0.004422  0.004392
#
# [5 rows x 180 columns]
